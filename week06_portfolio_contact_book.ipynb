# %% [markdown]
# <a href="https://colab.research.google.com/github/kisormoimercy/CSC101-ASSESSMENT2/blob/main/week06_portfolio_contact_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# contacts and phone number
Contacts = {
    "Angel": "342-0385",
    "Belinda": "211-6799",
    "Caren": "680-4789"
}

#add key and value
Contacts["Mercy"] ="0422-9131"

print(Contacts)
# Out:
# {'Angel': '342-0385', 'Belinda': '211-6799', 'Caren': '680-4789', 'Mercy': '0422-9131'}

# %%
contacts = {
    "Angel": "342-0385",
    "Belinda": "211-6799",
    "Caren": "680-4789",
    "Mercy": "0422-9131"
}

# update an existing contact
contacts["Belinda"] = "914-1234"

print(contacts)
# Out:
# {'Angel': '342-0385', 'Belinda': '914-1234', 'Caren': '680-4789', 'Mercy': '0422-9131'}

# %%
contacts = {
    "Angel": "342-0385",
    "Belinda": "914-2134",
    "Caren": "680-4789",
    "Mercy": "0422-9131"
}
for name in contacts:
    print(name, contacts[name])
# Out:
# Angel 342-0385
# Belinda 914-2134
# Caren 680-4789
# Mercy 0422-9131

# %%
contacts = {
    "Angel": {
        "phone": "342-0385",
        "email": "angel@gmail.com"
    },
    "Belinda": {
        "phone": "914-2134",
        "email": "belinda@gmail.com"
    },
    "Caren": {
        "phone": "680-4789",
        "email": "caren16@gmail.com"
    },
    "Mercy": {
        "phone": "0422-9131",
        "email": "mercy13@gmail.com"
    }
}

for name in contacts:
    print(name, contacts[name]["phone"], contacts[name]["email"])
# Out:
# Angel 342-0385 angel@gmail.com
# Belinda 914-2134 belinda@gmail.com
# Caren 680-4789 caren16@gmail.com
# Mercy 0422-9131 mercy13@gmail.com
